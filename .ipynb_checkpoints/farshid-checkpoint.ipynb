# %% [markdown]
# # Farshid PirahanSiah #
# ## 16 July 2019
# ### Workshop OpenCV all example in one file
#
# use Ctrl + '/' to undo comment
#
# run jupyter in admin mode

# %%
### if you installed all these package 2 min
# !python -m pip install --upgrade pip
## pre install
# !pip install -q numpy
# !pip install -q panda
# # TensorFlow 2
# !pip install -q tensorflow-gpu==2.0.0-beta1
# !pip install -q tensorflow_hub
# !pip install -q tensorflow_datasets
# !pip install -q jupyter-tensorboard
# Image Processing
# !pip install -q imageio
# !pip install -q opencv-python
# !pip install -q opencv-contrib-python
# !pip install -q bokeh
# !pip install -q Pillow
# Python
# !pip install -q pyreadline
# !pip install -q seaborn
# !pip install -q ibm-cos-sdk
#
# !pip install -q pyyaml requests

#!pip install -q ipython
#!pip install -q pyinstaller

print('step 1')
# 
# !pip install -q --user nbmultitask
# !pip install -q tqdm
#Django full-stack web framework; Flask web framework
# !pip install -q Flask
# !pip install -q Django
#
##!pip -q install autobahn
#!pip install -q kiteconnect
# commands 
##!python -m tensorboard.main --logdir=/farshid/
##tensorboard --logdir=logs/
print('step 2')

# %load_ext tensorboard
# %matplotlib inline 
# %config IPCompleter.greedy=True
# %matplotlib notebook
# Out:
# Requirement already up-to-date: pip in /home/farshid/anaconda3/lib/python3.7/site-packages (19.1.1)
# step 1
# step 2

# %%
import datetime


import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

import random
import pickle

import tqdm.auto
from tqdm import tqdm



import argparse
import sys
import numpy as np
import os.path

#from nbmultitask import ThreadWithLogAndControls

# Image Processing
import cv2 as cv
from IPython.display import Image

import matplotlib.pyplot as plt
# TensorFlow 2
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.python.ops.array_ops import placeholder
from tensorflow.python.training.gradient_descent import GradientDescentOptimizer
from tensorflow.python.summary.writer.writer import FileWriter

tf.compat.v1.disable_eager_execution()
#tf.debugging.set_log_device_placement(True)

# %%
# from numba import cuda
# len(cuda.gpus)
# cuda.gpus[0].name

# !watch -n 2 nvidia-smi
cv.__version__
#tf.__version__
#tf.test.is_gpu_available
# print(tf.test.is_gpu_available())
# tf.test.is_gpu_available(cuda_only=False) 
# tf.test.gpu_device_name()
# Out:
# '4.1.0'
